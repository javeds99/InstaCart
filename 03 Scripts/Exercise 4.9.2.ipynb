# %% [markdown]
# # Exercise 4.9 (Part 2)

# %% [markdown]
# # Steps 1-2

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import scipy
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\javed\instacart Basket Analysis'

# %%
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final.pkl'))

# %%
#2. Create a bar chart, a histogram, a scatterplot, and a line chart.
days = df['order_hour_of_day'].value_counts().plot.bar(color = ['green'])

# %%
df['prices'].value_counts().plot.hist(bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
np.random.seed(4)
dev = np.random.rand(len(df)) <= 0.7

# %%
big = df[dev]

# %%
small = df[~dev]

# %%
df2 = small[['orders_day_of_week', 'prices']]

# %%
line = sns.lineplot(data = df2, x = 'orders_day_of_week', y= 'prices')

# %%
line.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'prices_by_hour1.jpeg'))

# %% [markdown]
# # Steps 3-8

# %%
#3. Create a histogram of the “order_hour_of_day” column.
df['age_fam_profile'].value_counts().plot.bar(color =  'blue')
# Out:
# <AxesSubplot:>

# %%
df.groupby('user_id')agg.

# %% [markdown]
# The histogram shows

# %%
#4. Create a bar chart from the “loyalty_flag” column.
bar = df['price_range'].value_counts().plot.bar(color = 'green')

# %%
#5. Check whether there’s a difference in expenditure(price) depending on the hour of the day.
line = df[:3000000]

# %%
np.random.seed(4)
dev = np.random.rand(len(df)) <= 0.7

# %%
big = df[dev]

# %%
small = df[~dev]

# %%
df2 = small[['order_hour_of_day', 'max_order']]

# %%
line = sns.lineplot(data = df2, x = 'order_hour_of_day', y= 'max_order')

# %%
line.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'prices_by_hour2.jpeg'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   user_id                1000000 non-null  int64
#  1   First Name             947771 non-null   object
#  2   Surnam                 1000000 non-null  object
#  3   Gender                 1000000 non-null  object
#  4   STATE                  1000000 non-null  object
#  5   Age                    1000000 non-null  int64
#  6   n_dependants           1000000 non-null  int64
#  7   fam_status             1000000 non-null  object
#  8   income                 1000000 non-null  int64
#  9   order_id               1000000 non-null  int64
#  10  order_number           1000000 non-null  int64
#  11  orders_day_of_week     1000000 non-null  int64
#  12  order_hour_of_day      1000000 non-null  int64
#  13  product_id             1000000 non-null  int64
# ...

# %% [markdown]
# The higher priced items are normally sold during the first 5 hours.

# %%
#7. Create a scatterplot to explore whether there’s a connection between age and spending power.
sp= sns.scatterplot(x= 'region' , y= '', data = df)

# %% [markdown]
# The scatterplot shows that while some younger customers(under 30) have a large income, majority of the customers with a lot of spending power are older customers.

# %%
#8. Export your visualizations as “.png” files in your relevant project folder.
line.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'prices_by_hour.jpeg'))

# %%
bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'bar.jpeg'))

# %%
days.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'days.jpeg'))

# %%
dfd = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
dfd.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing
